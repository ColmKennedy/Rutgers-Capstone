# %%
import pandas as pd
pd.set_option('display.max_rows', 1000)
import datetime

# %%
bnb = pd.read_csv('data/bnbClean.csv')

# %%
bnb
# Out:
#        Unnamed: 0        id  \
# 0               1      2539
# 1               2      2595
# 2               3      3647
# 3               4      3831
# 4               5      5022
# ...           ...       ...
# 39113       39114  36484665
# 39114       39115  36485057
# 39115       39116  36485431
# 39116       39117  36485609
# 39117       39118  36487245
#
#                                                     name   host id  \
# 0                     Clean & quiet apt home by the park      2787
# 1                                  Skylit Midtown Castle      2845
# 2                    THE VILLAGE OF HARLEM....NEW YORK !      4632
# 3                        Cozy Entire Floor of Brownstone      4869
# 4       Entire Apt: Spacious Studio/Loft by central park      7192
# ...                                                  ...       ...
# 39113    Charming one bedroom - newly renovated rowhouse   8232441
# 39114      Affordable room in Bushwick/East Williamsburg   6570630
# ...

# %%
bnb.isna().sum()
# Out:
# Unnamed: 0                      0
# id                              0
# name                            0
# host id                         0
# host name                       0
# neighbourhood group             0
# neighbourhood                   0
# latitude                        0
# longitude                       0
# room and type                   0
# minimum nights                  0
# number of reviews (total)       0
# last review (date)           7978
# reviews per month               0
# floor                           0
# noise.dB.                       0
# price                           0
# dtype: int64

# %%
bnb['last review (date)'].fillna(datetime.min_value,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/w8/kd8t0x396b5fp5j1x25nb9lm0000gn/T/ipykernel_2598/1337093868.py in <module>
# ----> 1 bnb['last review (date)'].fillna(datetime.min_value,inplace=True)
#
# AttributeError: module 'datetime' has no attribute 'min_value'

# %%
bnb['last review (date)']
# Out:
# 0        2018-10-19 00:00:00
# 1        2019-05-21 00:00:00
# 2
# 3        2019-07-05 00:00:00
# 4        2018-11-19 00:00:00
#                 ...
# 39113
# 39114
# 39115
# 39116
# 39117
# Name: last review (date), Length: 39118, dtype: object
